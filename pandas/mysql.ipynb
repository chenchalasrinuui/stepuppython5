# %%
from mysql.connector import connect # pip install mysql-connector-python

# %%
con=connect(
    host="localhost",
    user="root",
    password="root",
    database="world"
)

# %%
myCursor=con.cursor()

# %%
query="select * from country"

# %%
myCursor.execute(query)

# %%
result=myCursor.fetchall()

# %%
import pandas as pd

# %%
columns=["Code","Name","Contient","Region","SurfaceArea","IndependentYear","Population","LifeExpectancy","GNP","GNP_old","LocalName","GovernmentForm","HeadOfState","Capital","Code2"]

# %%
df=pd.DataFrame(result,columns=columns)

# %%
df
# Out:
#     Code          Name       Contient                     Region SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean      193.00
# 1    AFG   Afghanistan           Asia  Southern and Central Asia   652090.00
# 2    AGO        Angola         Africa             Central Africa  1246700.00
# 3    AIA      Anguilla  North America                  Caribbean       96.00
# 4    ALB       Albania         Europe            Southern Europe    28748.00
# ..   ...           ...            ...                        ...         ...
# 234  YEM         Yemen           Asia                Middle East   527968.00
# 235  YUG    Yugoslavia         Europe            Southern Europe   102173.00
# 236  ZAF  South Africa         Africa            Southern Africa  1221037.00
# 237  ZMB        Zambia         Africa             Eastern Africa   752618.00
# 238  ZWE      Zimbabwe         Africa             Eastern Africa   390757.00
#
# ...

# %%
df.shape
# Out:
# (239, 15)

# %%
df.shape[0]
# Out:
# 239

# %%
df.shape[1]
# Out:
# 15

# %%
list(df["Name"])
# Out:
# ['Aruba',
#  'Afghanistan',
#  'Angola',
#  'Anguilla',
#  'Albania',
#  'Andorra',
#  'Netherlands Antilles',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'American Samoa',
#  'Antarctica',
#  'French Southern territories',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas',
#  'Bosnia and Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei',
#  'Bhutan',
#  'Bouvet Island',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Cocos (Keeling) Islands',
#  'Switzerland',
#  'Chile',
#  'China',
#  'Côte d’Ivoire',
#  'Cameroon',
#  'Congo, The Democratic Republic of the',
#  'Congo',
#  'Cook Islands',
#  'Colombia',
#  'Comoros',
#  'Cape Verde',
#  'Costa Rica',
#  'Cuba',
#  'Christmas Island',
#  'Cayman Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
# ...

# %%
df1=df[["Name","Population"]]

# %%
df2=df1.sort_values(by="Population",ascending=False)

# %%
df2.iloc[0:1]
# Out:
#      Name  Population
# 41  China  1277558000

# %%
df2.loc[41]
# Out:
# Name               China
# Population    1277558000
# Name: 41, dtype: object

# %%
df3=df2.head(1)

# %%
df3['Population']
# Out:
# 41    1277558000
# Name: Population, dtype: int64

# %%
df[df["Population"]>838383838]
# Out:
#    Code   Name Contient                     Region SurfaceArea  \
# 41  CHN  China     Asia               Eastern Asia  9572900.00
# 99  IND  India     Asia  Southern and Central Asia  3287263.00
#
#     IndependentYear  Population LifeExpectancy        GNP    GNP_old  \
# 41          -1523.0  1277558000           71.4  982268.00  917719.00
# 99           1947.0  1013662000           62.5  447114.00  430572.00
#
#        LocalName    GovernmentForm               HeadOfState  Capital Code2
# 41      Zhongquo  People'sRepublic               Jiang Zemin   1891.0    CN
# 99  Bharat/India  Federal Republic  Kocheril Raman Narayanan   1109.0    IN

# %%
df4=df[df["Contient"] == 'Asia']

# %%
df4
# Out:
#     Code                  Name Contient                     Region  \
# 1    AFG           Afghanistan     Asia  Southern and Central Asia
# 7    ARE  United Arab Emirates     Asia                Middle East
# 9    ARM               Armenia     Asia                Middle East
# 16   AZE            Azerbaijan     Asia                Middle East
# 21   BGD            Bangladesh     Asia  Southern and Central Asia
# 23   BHR               Bahrain     Asia                Middle East
# 32   BRN                Brunei     Asia             Southeast Asia
# 33   BTN                Bhutan     Asia  Southern and Central Asia
# 41   CHN                 China     Asia               Eastern Asia
# 54   CYP                Cyprus     Asia                Middle East
# 77   GEO               Georgia     Asia                Middle East
# 92   HKG             Hong Kong     Asia               Eastern Asia
# 98   IDN             Indonesia     Asia             Southeast Asia
# ...

# %%
df4.shape
# Out:
# (51, 15)

# %%
df5=df4.sort_values(by="Population",ascending=False)

# %%
df5
# Out:
#     Code                  Name Contient                     Region  \
# 41   CHN                 China     Asia               Eastern Asia
# 99   IND                 India     Asia  Southern and Central Asia
# 98   IDN             Indonesia     Asia             Southeast Asia
# 164  PAK              Pakistan     Asia  Southern and Central Asia
# 21   BGD            Bangladesh     Asia  Southern and Central Asia
# 109  JPN                 Japan     Asia               Eastern Asia
# 230  VNM               Vietnam     Asia             Southeast Asia
# 168  PHL           Philippines     Asia             Southeast Asia
# 102  IRN                  Iran     Asia  Southern and Central Asia
# 215  TUR                Turkey     Asia                Middle East
# 207  THA              Thailand     Asia             Southeast Asia
# 116  KOR           South Korea     Asia               Eastern Asia
# 140  MMR               Myanmar     Asia             Southeast Asia
# ...

# %%
df
# Out:
#     Code          Name       Contient                     Region SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean      193.00
# 1    AFG   Afghanistan           Asia  Southern and Central Asia   652090.00
# 2    AGO        Angola         Africa             Central Africa  1246700.00
# 3    AIA      Anguilla  North America                  Caribbean       96.00
# 4    ALB       Albania         Europe            Southern Europe    28748.00
# ..   ...           ...            ...                        ...         ...
# 234  YEM         Yemen           Asia                Middle East   527968.00
# 235  YUG    Yugoslavia         Europe            Southern Europe   102173.00
# 236  ZAF  South Africa         Africa            Southern Africa  1221037.00
# 237  ZMB        Zambia         Africa             Eastern Africa   752618.00
# 238  ZWE      Zimbabwe         Africa             Eastern Africa   390757.00
#
# ...

# %%
df.shape
# Out:
# (239, 15)

# %%
df.dropna()
# Out:
#     Code                  Name       Contient           Region SurfaceArea  \
# 2    AGO                Angola         Africa   Central Africa  1246700.00
# 4    ALB               Albania         Europe  Southern Europe    28748.00
# 7    ARE  United Arab Emirates           Asia      Middle East    83600.00
# 8    ARG             Argentina  South America    South America  2780400.00
# 9    ARM               Armenia           Asia      Middle East    29800.00
# ..   ...                   ...            ...              ...         ...
# 233  WSM                 Samoa        Oceania        Polynesia     2831.00
# 234  YEM                 Yemen           Asia      Middle East   527968.00
# 236  ZAF          South Africa         Africa  Southern Africa  1221037.00
# 237  ZMB                Zambia         Africa   Eastern Africa   752618.00
# 238  ZWE              Zimbabwe         Africa   Eastern Africa   390757.00
#
# ...

# %%
df.dropna(axis=1)
# Out:
#     Code          Name       Contient                     Region SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean      193.00
# 1    AFG   Afghanistan           Asia  Southern and Central Asia   652090.00
# 2    AGO        Angola         Africa             Central Africa  1246700.00
# 3    AIA      Anguilla  North America                  Caribbean       96.00
# 4    ALB       Albania         Europe            Southern Europe    28748.00
# ..   ...           ...            ...                        ...         ...
# 234  YEM         Yemen           Asia                Middle East   527968.00
# 235  YUG    Yugoslavia         Europe            Southern Europe   102173.00
# 236  ZAF  South Africa         Africa            Southern Africa  1221037.00
# 237  ZMB        Zambia         Africa             Eastern Africa   752618.00
# 238  ZWE      Zimbabwe         Africa             Eastern Africa   390757.00
#
# ...

# %%
df.fillna(0)
# Out:
#     Code          Name       Contient                     Region SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean      193.00
# 1    AFG   Afghanistan           Asia  Southern and Central Asia   652090.00
# 2    AGO        Angola         Africa             Central Africa  1246700.00
# 3    AIA      Anguilla  North America                  Caribbean       96.00
# 4    ALB       Albania         Europe            Southern Europe    28748.00
# ..   ...           ...            ...                        ...         ...
# 234  YEM         Yemen           Asia                Middle East   527968.00
# 235  YUG    Yugoslavia         Europe            Southern Europe   102173.00
# 236  ZAF  South Africa         Africa            Southern Africa  1221037.00
# 237  ZMB        Zambia         Africa             Eastern Africa   752618.00
# 238  ZWE      Zimbabwe         Africa             Eastern Africa   390757.00
#
# ...

# %%
df
# Out:
#     Code          Name       Contient                     Region SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean      193.00
# 1    AFG   Afghanistan           Asia  Southern and Central Asia   652090.00
# 2    AGO        Angola         Africa             Central Africa  1246700.00
# 3    AIA      Anguilla  North America                  Caribbean       96.00
# 4    ALB       Albania         Europe            Southern Europe    28748.00
# ..   ...           ...            ...                        ...         ...
# 234  YEM         Yemen           Asia                Middle East   527968.00
# 235  YUG    Yugoslavia         Europe            Southern Europe   102173.00
# 236  ZAF  South Africa         Africa            Southern Africa  1221037.00
# 237  ZMB        Zambia         Africa             Eastern Africa   752618.00
# 238  ZWE      Zimbabwe         Africa             Eastern Africa   390757.00
#
# ...

# %%
df.rename(columns={"Name":"Country Name"},inplace=True)

# %%
df
# Out:
#     Code  Country Name       Contient                     Region SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean      193.00
# 1    AFG   Afghanistan           Asia  Southern and Central Asia   652090.00
# 2    AGO        Angola         Africa             Central Africa  1246700.00
# 3    AIA      Anguilla  North America                  Caribbean       96.00
# 4    ALB       Albania         Europe            Southern Europe    28748.00
# ..   ...           ...            ...                        ...         ...
# 234  YEM         Yemen           Asia                Middle East   527968.00
# 235  YUG    Yugoslavia         Europe            Southern Europe   102173.00
# 236  ZAF  South Africa         Africa            Southern Africa  1221037.00
# 237  ZMB        Zambia         Africa             Eastern Africa   752618.00
# 238  ZWE      Zimbabwe         Africa             Eastern Africa   390757.00
#
# ...

# %%
val=df.groupby(['Contient','Country Name'])

# %%
df7=val.first()

# %%
df7
# Out:
#                                              Code           Region  \
# Contient      Country Name
# Africa        Algeria                         DZA  Northern Africa
#               Angola                          AGO   Central Africa
#               Benin                           BEN   Western Africa
#               Botswana                        BWA  Southern Africa
#               British Indian Ocean Territory  IOT   Eastern Africa
# ...                                           ...              ...
# South America Paraguay                        PRY    South America
#               Peru                            PER    South America
#               Suriname                        SUR    South America
#               Uruguay                         URY    South America
#               Venezuela                       VEN    South America
#
#                                              SurfaceArea  IndependentYear  \
# Contient      Country Name
# ...

# %%
df
