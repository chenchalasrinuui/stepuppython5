# %%
import pandas as pd

# %%
web_url='https://en.wikipedia.org/wiki/Sachin_Tendulkar'

# %%
df1=pd.read_html(web_url)

# %%
len(df1)
# Out:
# 39

# %%
df1[0]
# Out:
#                                                     0  \
# 0                                   Tendulkar in 2015
# 1                                Personal information
# 2                                           Full name
# 3                                                Born
# 4                                            Nickname
# 5                                              Height
# 6                                             Batting
# 7                                             Bowling
# 8                                                Role
# 9                                           Relations
# 10                                            Website
# 11                          International information
# 12                                      National side
# 13                               Test debut (cap 187)
# 14                                          Last Test
# 15                                 ODI debut (cap 74)
# ...

# %%
df1[30]
# Out:
#              vteIndia squad – 1992 Cricket World Cup  \
# 0  1 Azharuddin (c) 2 Kapil Dev 3 Srikkanth 4 Sha...
#
#            vteIndia squad – 1992 Cricket World Cup.1  \
# 0  1 Azharuddin (c) 2 Kapil Dev 3 Srikkanth 4 Sha...
#
#    vteIndia squad – 1992 Cricket World Cup.2
# 0                                        NaN

# %%
df1[23]
# Out:
#   vteRecipients of Khel Ratna  \
# 0                   1991–2000
# 1                   2001–2010
# 2                   2011–2020
# 3                   2021–2030
#
#                        vteRecipients of Khel Ratna.1
# 0  Viswanathan Anand (1991–1992) Geet Sethi (1992...
# 1  Abhinav Bindra (2001) K. M. Beenamol and Anjal...
# 2  Gagan Narang (2011) Vijay Kumar and Yogeshwar ...
# 3  Avani Lekhara, Neeraj Chopra, Ravi Kumar Dahiy...
