# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#      Order id Customer name  Customer id                Product name  \
# 0      192837        Partha            8        Apple iPad 10.2-inch
# 1      192838         Vinay           10               Flatscreen TV
# 2      192839       Lavanya           16                20in Monitor
# 3      192840         Mohan           24  Bose SoundSport Headphones
# 4      192841         Kedar            2                Google Phone
# ..        ...           ...          ...                         ...
# 895    193732        Balaji           12          Samsung Galaxy S20
# 896    193733       Neelima           19      27in 4K Gaming Monitor
# 897    193734        Siddhu           18                Google Phone
# 898    193735         Vinay           10                20in Monitor
# 899    193736     Madhurima            7            27in FHD Monitor
#
#      Product cost
# 0           59000
# 1           65999
# 2           75000
# 3           55000
# 4           59000
# ..            ...
# ...

# %%
df[df['Product cost'] > 70000]
# Out:
#      Order id Customer name  Customer id            Product name  Product cost
# 2      192839       Lavanya           16            20in Monitor         75000
# 5      192842       Karteek            4      LG Washing Machine         75000
# 7      192844       Pradhan           17      Macbook Pro Laptop         75999
# 8      192845        Balaji           12      Macbook Pro Laptop         75000
# 21     192858         Mohan           24  LG ThinQ Refrigerator          75999
# ..        ...           ...          ...                     ...           ...
# 886    193723          Hema            6               LG Mobile         75999
# 887    193724         Shafi            3  LG ThinQ Refrigerator          75999
# 888    193725   Mallikarjun           13            Google Phone         75999
# 893    193730       Lavanya           16               LG Mobile         75999
# 896    193733       Neelima           19  27in 4K Gaming Monitor         75999
#
# [134 rows x 5 columns]

# %%
df[(df["Product name"] == 'Google Phone') & (df['Product cost'] > 70000)]
# Out:
#      Order id Customer name  Customer id  Product name  Product cost
# 38     192875        Balaji           12  Google Phone         75000
# 516    193353       Lavanya           16  Google Phone         75000
# 528    193365       Lavanya           16  Google Phone         75000
# 618    193455         Vijay            9  Google Phone         75000
# 631    193468         Kedar            2  Google Phone         75999
# 835    193672       Karteek            4  Google Phone         75000
# 888    193725   Mallikarjun           13  Google Phone         75999

# %%
df[(df["Product name"] == 'Google Phone') | (df['Product cost'] > 70000)]
# Out:
#      Order id Customer name  Customer id            Product name  Product cost
# 2      192839       Lavanya           16            20in Monitor         75000
# 4      192841         Kedar            2            Google Phone         59000
# 5      192842       Karteek            4      LG Washing Machine         75000
# 7      192844       Pradhan           17      Macbook Pro Laptop         75999
# 8      192845        Balaji           12      Macbook Pro Laptop         75000
# ..        ...           ...          ...                     ...           ...
# 888    193725   Mallikarjun           13            Google Phone         75999
# 892    193729    Chaithanya           14            Google Phone         65000
# 893    193730       Lavanya           16               LG Mobile         75999
# 896    193733       Neelima           19  27in 4K Gaming Monitor         75999
# 897    193734        Siddhu           18            Google Phone         69999
#
# [175 rows x 5 columns]

# %%
df[df["Customer name"] == 'Vinay']
# Out:
#      Order id Customer name  Customer id              Product name  \
# 1      192838         Vinay           10             Flatscreen TV
# 85     192922         Vinay           10        Macbook Pro Laptop
# 154    192991         Vinay           10                 LG Mobile
# 161    192998         Vinay           10                  iPhone 9
# 164    193001         Vinay           10                  iPhone 8
# 192    193029         Vinay           10  Apple Airpods Headphones
# 247    193084         Vinay           10                  iPhone 9
# 255    193092         Vinay           10  Apple Airpods Headphones
# 330    193167         Vinay           10                 iPhone 11
# 331    193168         Vinay           10                 iPhone 11
# 380    193217         Vinay           10        Samsung Galaxy S20
# 431    193268         Vinay           10                  iPhone 9
# 442    193279         Vinay           10    27in 4K Gaming Monitor
# ...

# %%
df1=df[df["Customer name"] == 'Vinay']

# %%
df1.iloc[0]['Customer id']
# Out:
# 10

# %%
df2=df[df["Customer name"] == 'Vinay']

# %%
df2["Order id"]
# Out:
# 1      192838
# 85     192922
# 154    192991
# 161    192998
# 164    193001
# 192    193029
# 247    193084
# 255    193092
# 330    193167
# 331    193168
# 380    193217
# 431    193268
# 442    193279
# 444    193281
# 451    193288
# 454    193291
# 474    193311
# 512    193349
# 518    193355
# 543    193380
# 563    193400
# 575    193412
# 587    193424
# 599    193436
# 617    193454
# 682    193519
# 695    193532
# 855    193692
# 881    193718
# 898    193735
# Name: Order id, dtype: int64

# %%
df.sort_values(by="Customer name",ascending=False)
# Out:
#      Order id Customer name  Customer id              Product name  \
# 431    193268         Vinay           10                  iPhone 9
# 444    193281         Vinay           10    34in Ultrawide Monitor
# 512    193349         Vinay           10    Samsung Galaxy S9 Plus
# 855    193692         Vinay           10              20in Monitor
# 563    193400         Vinay           10                       NaN
# ..        ...           ...          ...                       ...
# 210    193047        Balaji           12             Flatscreen TV
# 730    193567        Balaji           12        Samsung Galaxy S20
# 447    193284        Balaji           12        Samsung Galaxy S20
# 870    193707        Balaji           12                  iPhone 9
# 693    193530        Balaji           12  Apple Airpods Headphones
#
#      Product cost
# 431         65000
# 444         50000
# 512         51999
# 855         61000
# 563         59000
# ..            ...
# 210         75999
# ...

# %%
df5=df.sort_values(by="Product cost",ascending=True)

# %%
min=df5.iloc[0]['Product cost']

# %%
min
# Out:
# 50000

# %%
df5.shape[0]
# Out:
# 900

# %%
max=df5.iloc[df5.shape[0]-1]['Product cost']

# %%
max
# Out:
# 75999
