# %%
import matplotlib.pyplot as plt

# %%
labels=["SSC",'INTER',"B.Tech",'M.Tech']

# %%
std1=[80,45,88,60]
std2=[88,89,35,99]

# %%
plt.plot(labels,std1,std2)
plt.xlabel('Academcs')
plt.ylabel("Percentage")
plt.show()
